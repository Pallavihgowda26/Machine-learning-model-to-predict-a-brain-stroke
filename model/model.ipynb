# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
from functools import reduce

# %%
df = pd.read_csv('brain_stroke.csv',encoding= 'unicode_escape')

# %%
df
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 0       Male  67.0             0              1          Yes        Private
# 1       Male  80.0             0              1          Yes        Private
# 2     Female  49.0             0              0          Yes        Private
# 3     Female  79.0             1              0          Yes  Self-employed
# 4       Male  81.0             0              0          Yes        Private
# ...      ...   ...           ...            ...          ...            ...
# 4976    Male  41.0             0              0           No        Private
# 4977    Male  40.0             0              0          Yes        Private
# 4978  Female  45.0             1              0          Yes       Govt_job
# 4979    Male  40.0             0              0          Yes        Private
# 4980  Female  80.0             1              0          Yes        Private
#
#      Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0             Urban             228.69  36.6  formerly smoked       1
# 1             Rural             105.92  32.5     never smoked       1
# 2             Urban             171.23  34.4           smokes       1
# 3             Rural             174.12  24.0     never smoked       1
# 4             Urban             186.21  29.0  formerly smoked       1
# ...             ...                ...   ...              ...     ...
# 4976          Rural              70.15  29.8  formerly smoked       0
# 4977          Urban             191.15  31.1           smokes       0
# 4978          Rural              95.02  31.8           smokes       0
# 4979          Rural              83.94  30.0           smokes       0
# 4980          Urban              83.75  29.1     never smoked       0
#
# [4981 rows x 11 columns]

# %%
df.dtypes
# Out:
# gender                object
# age                  float64
# hypertension           int64
# heart_disease          int64
# ever_married          object
# work_type             object
# Residence_type        object
# avg_glucose_level    float64
# bmi                  float64
# smoking_status        object
# stroke                 int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4981 entries, 0 to 4980
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   gender             4981 non-null   object
#  1   age                4981 non-null   float64
#  2   hypertension       4981 non-null   int64
#  3   heart_disease      4981 non-null   int64
#  4   ever_married       4981 non-null   object
#  5   work_type          4981 non-null   object
#  6   Residence_type     4981 non-null   object
#  7   avg_glucose_level  4981 non-null   float64
#  8   bmi                4981 non-null   float64
#  9   smoking_status     4981 non-null   object
#  10  stroke             4981 non-null   int64
# dtypes: float64(3), int64(3), object(5)
# memory usage: 428.2+ KB

# %%
df['stroke'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
import seaborn as sns

# %%
plt.style.use('seaborn')
df['stroke'].hist(bins=20)
# Out:
# C:\Users\IT Support\AppData\Local\Temp\ipykernel_6392\3103517307.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')
# <Axes: >

# %%
plt.style.use('seaborn')
df['smoking_status'].hist(bins=20)
# Out:
# C:\Users\IT Support\AppData\Local\Temp\ipykernel_6392\1168169343.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')
# <Axes: >

# %%
plt.style.use('seaborn')
df['Residence_type'].hist(bins=20)
# Out:
# C:\Users\IT Support\AppData\Local\Temp\ipykernel_6392\47543375.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')
# <Axes: >

# %%
plt.style.use('seaborn')
df['work_type'].hist(bins=20)
# Out:
# C:\Users\IT Support\AppData\Local\Temp\ipykernel_6392\1791015201.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')
# <Axes: >

# %%
plt.style.use('seaborn')
df['ever_married'].hist(bins=20)
# Out:
# C:\Users\IT Support\AppData\Local\Temp\ipykernel_6392\1496219395.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')
# <Axes: >

# %%
plt.style.use('seaborn')
df['gender'].hist(bins=20)
# Out:
# C:\Users\IT Support\AppData\Local\Temp\ipykernel_6392\4067332346.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')
# <Axes: >

# %%
df['stroke'].value_counts()
# Out:
# stroke
# 0    4733
# 1     248
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4981 entries, 0 to 4980
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   gender             4981 non-null   object
#  1   age                4981 non-null   float64
#  2   hypertension       4981 non-null   int64
#  3   heart_disease      4981 non-null   int64
#  4   ever_married       4981 non-null   object
#  5   work_type          4981 non-null   object
#  6   Residence_type     4981 non-null   object
#  7   avg_glucose_level  4981 non-null   float64
#  8   bmi                4981 non-null   float64
#  9   smoking_status     4981 non-null   object
#  10  stroke             4981 non-null   int64
# dtypes: float64(3), int64(3), object(5)
# memory usage: 428.2+ KB

# %%
df['gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df.loc[df['gender']=='Male','gender'] = 0
df.loc[df['gender']=='Female','gender'] = 1

# %%
df['ever_married'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df.loc[df['ever_married']=='Yes','ever_married'] = 0
df.loc[df['ever_married']=='No','ever_married'] = 1

# %%
df['work_type'].unique()
# Out:
# array(['Private', 'Self-employed', 'Govt_job', 'children'], dtype=object)

# %%
df.loc[df['work_type']=='Private','work_type'] = 0
df.loc[df['work_type']=='Self-employed','work_type'] = 1 
df.loc[df['work_type']=='Govt_job','work_type'] = 2
df.loc[df['work_type']=='children','work_type'] = 3

# %%
df['Residence_type'].unique()
# Out:
# array(['Urban', 'Rural'], dtype=object)

# %%
df.loc[df['Residence_type']=='Urban', 'Residence_type'] = 0
df.loc[df['Residence_type']=='Rural', 'Residence_type'] = 1

# %%
df['smoking_status'].unique()
# Out:
# array(['formerly smoked', 'never smoked', 'smokes', 'Unknown'],
#       dtype=object)

# %%
df.loc[df['smoking_status']=='formerly smoked', 'smoking_status'] = 0
df.loc[df['smoking_status']=='never smoked', 'smoking_status'] = 1
df.loc[df['smoking_status']=='smokes', 'smoking_status'] = 2
df.loc[df['smoking_status']=='Unknown', 'smoking_status'] = 3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4981 entries, 0 to 4980
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   gender             4981 non-null   object
#  1   age                4981 non-null   float64
#  2   hypertension       4981 non-null   int64
#  3   heart_disease      4981 non-null   int64
#  4   ever_married       4981 non-null   object
#  5   work_type          4981 non-null   object
#  6   Residence_type     4981 non-null   object
#  7   avg_glucose_level  4981 non-null   float64
#  8   bmi                4981 non-null   float64
#  9   smoking_status     4981 non-null   object
#  10  stroke             4981 non-null   int64
# dtypes: float64(3), int64(3), object(5)
# memory usage: 428.2+ KB

# %%
sns.distplot(df["age"])
df['age'].skew()
# Out:
# C:\Users\IT Support\AppData\Local\Temp\ipykernel_6392\2229169427.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["age"])
# -0.14400119564600208

# %%
sns.distplot(df['avg_glucose_level'])
df['avg_glucose_level'].skew
# Out:
# C:\Users\IT Support\AppData\Local\Temp\ipykernel_6392\207288889.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['avg_glucose_level'])
# <bound method NDFrame._add_numeric_operations.<locals>.skew of 0       228.69
# 1       105.92
# 2       171.23
# 3       174.12
# 4       186.21
#          ...
# 4976     70.15
# 4977    191.15
# 4978     95.02
# 4979     83.94
# 4980     83.75
# Name: avg_glucose_level, Length: 4981, dtype: float64>

# %%
corr = df.corr()
sns.heatmap(corr, annot=True)
# Out:
# <Axes: >

# %%
df.dtypes
# Out:
# gender                object
# age                  float64
# hypertension           int64
# heart_disease          int64
# ever_married          object
# work_type             object
# Residence_type        object
# avg_glucose_level    float64
# bmi                  float64
# smoking_status        object
# stroke                 int64
# dtype: object

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import RobustScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix

# %%
df['stroke'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
n = df['stroke'].value_counts()[0]

# %%
df_majority = df[df['stroke']== 0]
df_minority = df[df['stroke']== 1]

# %%
from sklearn.utils import resample

# %%
 
df_minority_upsampled = resample(df_minority,replace=True,n_samples = n,random_state=42)

df = pd.concat([df_majority,df_minority_upsampled])
df['stroke'].value_counts()
# Out:
# stroke
# 0    4733
# 1    4733
# Name: count, dtype: int64

# %%
df.dtypes
# Out:
# gender                object
# age                  float64
# hypertension           int64
# heart_disease          int64
# ever_married          object
# work_type             object
# Residence_type        object
# avg_glucose_level    float64
# bmi                  float64
# smoking_status        object
# stroke                 int64
# dtype: object

# %%
X = df.drop(['stroke'], axis=1).values

y = df['stroke'].values

# %%
X.shape
# Out:
# (9466, 10)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.20, random_state=101)

# %%
rfc = RandomForestClassifier(n_estimators=60, random_state=23)

# %%
rfc.fit(X_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=60, random_state=23)

# %%
rfc.score(X_train,y_train)
# Out:
# 1.0

# %%
from sklearn.metrics import accuracy_score
y_pred = rfc.predict(X_test )
accuracy_score(y_pred,y_test)
# Out:
# 0.9941921858500528

# %%
import sklearn.metrics

# %%
print(sklearn.metrics.classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99       970
#            1       0.99      1.00      0.99       924
#
#     accuracy                           0.99      1894
#    macro avg       0.99      0.99      0.99      1894
# weighted avg       0.99      0.99      0.99      1894

# %%
y_pred = rfc.predict(X_test )
y_true=y_test


from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_true,y_pred)
cm
# Out:
# array([[959,  11],
#        [  0, 924]], dtype=int64)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

f, ax=plt.subplots(figsize=(5,5))
sns.heatmap(cm,annot=True,linewidths=0.5,linecolor="red",fmt=".0f",ax=ax)
plt.xlabel("y_pred")
plt.ylabel("y_true")
plt.show()

# %%
import pickle

pickle.dump(rfc,open('brain_random.pkl','wb'))
random = pickle.load(open('brain_random.pkl','rb'))

# %%
from sklearn.ensemble import BaggingClassifier
models=BaggingClassifier()

# %%
models.fit(X_train,y_train)
# Out:
# BaggingClassifier()

# %%
models.score(X_train,y_train)
# Out:
# 0.9993396724775488

# %%
from sklearn.metrics import accuracy_score
y_pred = models.predict(X_test )
accuracy_score(y_pred,y_test)
# Out:
# 0.9825765575501584

# %%
print(sklearn.metrics.classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.98       970
#            1       0.97      1.00      0.98       924
#
#     accuracy                           0.98      1894
#    macro avg       0.98      0.98      0.98      1894
# weighted avg       0.98      0.98      0.98      1894

# %%
y_pred = models.predict(X_test )
y_true=y_test


from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_true,y_pred)
cm
# Out:
# array([[937,  33],
#        [  0, 924]], dtype=int64)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

f, ax=plt.subplots(figsize=(5,5))
sns.heatmap(cm,annot=True,linewidths=0.5,linecolor="red",fmt=".0f",ax=ax)
plt.xlabel("y_pred")
plt.ylabel("y_true")
plt.show()

# %%
import pickle

pickle.dump(models,open('brain_bagging.pkl','wb'))
bagging = pickle.load(open('brain_bagging.pkl','rb'))
